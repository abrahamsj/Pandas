# %% [markdown]
# ## Importing data
#
# Note:
# - Had to delete the first four lines of the file being used. Caused parser error.
# - 2 of the 3 files only had column names

# %%
pip install squarify
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import numpy as np
import random
# import squarify



health_df= pd.read_csv('data/World_Bank_Health_Data/Table_1.csv')
health_df2= pd.read_csv('data/World_Bank_Health_Data/Table2.csv')
health_df3= pd.read_csv('data/World_Bank_Health_Data/Table3.csv')


health_data = pd.merge(health_df, health_df2, on='Country Code')
# health_data = pd.merge(health_data, health_df3, on='SpecialNotes') 



health_data.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[37], line 11
#       6 import random
#       7 # import squarify
# ---> 11 health_df= pd.read_csv('data/World_Bank_Health_Data/Table_1.csv')
#      12 health_df2= pd.read_csv('data/World_Bank_Health_Data/Table2.csv')
#      13 health_df3= pd.read_csv('data/World_Bank_Health_Data/Table3.csv')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
health_df.shape
# Out:
# (20730, 67)

# %%
health_df = health_df.drop(['2021','Indicator Code'],axis=1)

health_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 health_df = health_df.drop(['2021','Indicator Code'],axis=1)
#       3 health_df
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
# ...

# %% [markdown]
# ## Deleting Nulls

# %%
health_df=health_df[health_df['1960'].fillna(0)]

health_df
# .round(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 health_df=health_df[health_df['1960'].fillna(0)]
#       3 health_df
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
# ...

# %%
health_df.shape
# Out:
# (20730, 67)

# %%
plt.scatter(y=health_df['1960'], x=health_df['2020'])
plt.xlabel('Year 1960')
plt.ylabel('Year 2020')
plt.show()

# %%
plt.plot(health_df['1960'])

# %%
plt.plot(health_df['2020'])
plt.xlabel('Data points Year 2020')
plt.show()

# %%
squarify.plot(sizes= health_df['Country'], color=colors)
plt.axis("off")
